# %%
import os
import pandas as pd

covid_df = pd.read_csv("coviddata.csv", encoding="utf-8")
covid_df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
fips= covid_df["fips"].unique()
fips_df = pd.DataFrame({"FIPS":fips})
fips_df
# Out:
#          FIPS
# 0     53061.0
# 1     17031.0
# 2      6059.0
# 3      4013.0
# 4      6037.0
# ...       ...
# 3214  48269.0
# 3215   2230.0
# 3216  32009.0
# 3217  48301.0
# 3218  15005.0
#
# [3219 rows x 1 columns]

# %%
# fips100_df=fips_df.sample(n=101,axis='rows')
# # #counties100_df["fips"].value_counts().sort_values()
# fips100_df
# Out:
#          FIPS
# 3149  31117.0
# 2923  72137.0
# 2095  31105.0
# 444   27013.0
# 2445  41015.0
# ...       ...
# 1348   8089.0
# 1823  42031.0
# 3031  16041.0
# 71    53031.0
# 365   50023.0
#
# [101 rows x 1 columns]

# %%
fips100_df.to_csv("100_counties.csv", index=False, header=True)

# %%
countydata_df= pd.read_csv("countydata.csv", encoding="utf-8")
countydata_df
# Out:
#            county county_ascii  county_fips state_id  state_name      lat  \
# 0     Los Angeles  Los Angeles         6037       CA  California  34.3207
# 1            Cook         Cook        17031       IL    Illinois  41.8401
# 2          Harris       Harris        48201       TX       Texas  29.8577
# 3        Maricopa     Maricopa         4013       AZ     Arizona  33.3490
# 4       San Diego    San Diego         6073       CA  California  33.0341
# ...           ...          ...          ...      ...         ...      ...
# 3137       Arthur       Arthur        31005       NE    Nebraska  41.5689
# 3138    McPherson    McPherson        31117       NE    Nebraska  41.5682
# 3139         King         King        48269       TX       Texas  33.6166
# 3140       Loving       Loving        48301       TX       Texas  31.8493
# 3141      Kalawao      Kalawao        15005       HI      Hawaii  21.1709
#
#            lng  population
# 0    -118.2248    10081570
# 1     -87.8168     5198275
# 2     -95.3936     4646630
# 3    -112.4915     4328810
# 4    -116.7353     3316073
# ...        ...         ...
# 3137 -101.6958         427
# 3138 -101.0605         395
# 3139 -100.2558         237
# 3140 -103.5799          98
# 3141 -156.9475          66
#
# [3142 rows x 8 columns]

# %%
fips100_df=pd.read_csv("100_counties.csv")

# %%
counties100data = pd.merge(fips100_df,countydata_df, left_on ="FIPS", right_on = "county_fips" )
counties100data.columns
# Out:
# Index(['FIPS', 'county', 'county_ascii', 'county_fips', 'state_id',
#        'state_name', 'lat', 'lng', 'population'],
#       dtype='object')

# %%
counties100data.to_csv("100_countiesdata.csv", index=False, header=True)

# %%
print(covid_df["date"].min())
print(covid_df["date"].max())
# Out:
# 2020-01-21
# 2021-03-17

# %%
covid_100_df=covid_df[covid_df["fips"].isin(counties100data["FIPS"])]
covid_100_df.head()
# Out:
#                date     county          state     fips  cases  deaths
# 648      2020-03-06  Jefferson     Washington  53031.0      1     0.0
# 701      2020-03-07  Berkshire  Massachusetts  25003.0      1     0.0
# 742      2020-03-07  Jefferson     Washington  53031.0      1     0.0
# 803      2020-03-08  Berkshire  Massachusetts  25003.0      1     0.0
# 854      2020-03-08  Jefferson     Washington  53031.0      1     0.0
# ...             ...        ...            ...      ...    ...     ...
# 1131224  2021-03-17    Clallam     Washington  53009.0   1007     8.0
# 1131235  2021-03-17  Jefferson     Washington  53031.0    338     2.0
# 1131299  2021-03-17    Raleigh  West Virginia  54081.0   5018    66.0
# 1131360  2021-03-17      Pepin      Wisconsin  55091.0    836     7.0
# 1131383  2021-03-17   Waushara      Wisconsin  55137.0   2423    35.0
#
# [34780 rows x 6 columns]

# %%
len(covid_100_df["fips"].unique())
# Out:
# 100

# %%
covid_100_df2=pd.merge(covid_100_df,counties100data[['county_fips', 'state_id',
       'state_name', 'lat', 'lng', 'population']],left_on="fips",right_on="county_fips")
covid_100_df2
# Out:
#              date        county       state     fips  cases  deaths  \
# 0      2020-03-06     Jefferson  Washington  53031.0      1     0.0
# 1      2020-03-07     Jefferson  Washington  53031.0      1     0.0
# 2      2020-03-08     Jefferson  Washington  53031.0      1     0.0
# 3      2020-03-09     Jefferson  Washington  53031.0      1     0.0
# 4      2020-03-10     Jefferson  Washington  53031.0      1     0.0
# ...           ...           ...         ...      ...    ...     ...
# 34775  2021-03-13  Powder River     Montana  30075.0    114     6.0
# 34776  2021-03-14  Powder River     Montana  30075.0    114     6.0
# 34777  2021-03-15  Powder River     Montana  30075.0    114     6.0
# 34778  2021-03-16  Powder River     Montana  30075.0    114     6.0
# 34779  2021-03-17  Powder River     Montana  30075.0    115     6.0
#
#        county_fips state_id  state_name      lat       lng  population
# 0            53031       WA  Washington  47.7489 -123.5952       31285
# 1            53031       WA  Washington  47.7489 -123.5952       31285
# 2            53031       WA  Washington  47.7489 -123.5952       31285
# 3            53031       WA  Washington  47.7489 -123.5952       31285
# 4            53031       WA  Washington  47.7489 -123.5952       31285
# ...            ...      ...         ...      ...       ...         ...
# 34775        30075       MT     Montana  45.3950 -105.6302        1607
# 34776        30075       MT     Montana  45.3950 -105.6302        1607
# 34777        30075       MT     Montana  45.3950 -105.6302        1607
# 34778        30075       MT     Montana  45.3950 -105.6302        1607
# 34779        30075       MT     Montana  45.3950 -105.6302        1607
#
# [34780 rows x 12 columns]
