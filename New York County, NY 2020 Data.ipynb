# %%
#Dependencies

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from datetime import datetime, timedelta
import csv
import matplotlib.dates as mdates

# %%
#Data files
newyork2020_county_path = "Resources/newyorkcountydata2020.csv"

#Ready the data
newyork2020_county = pd.read_csv(newyork2020_county_path)

#Display
newyork2020_county.head()
# Out:
#            region_name region_type period_begin period_end duration  \
# 0  New York County, NY      county     1/6/2020   2/2/2020  4 weeks
# 1  New York County, NY      county    1/13/2020   2/9/2020  4 weeks
# 2  New York County, NY      county    1/20/2020  2/16/2020  4 weeks
# 3  New York County, NY      county    1/27/2020  2/23/2020  4 weeks
# 4  New York County, NY      county     2/3/2020   3/1/2020  4 weeks
#
#    total_homes_sold  total_homes_sold_yoy  average_homes_sold  \
# 0               728              0.189542                 182
# 1               733              0.165342                 183
# 2               727              0.197694                 181
# 3               712              0.172982                 178
# 4               712              0.133758                 178
#
#    average_homes_sold_yoy  total_homes_sold_with_price_drops  ...  \
# 0                0.189542                                  7  ...
# ...

# %%
#Generate Line Plot of Total Homes Sold in 2020

plt.style.use('seaborn-whitegrid')
dates = newyork2020_county['period_begin']
dates = pd.to_datetime(dates)
plt.plot(dates,newyork2020_county['total_homes_sold'],color = 'red')
plt.gcf().autofmt_xdate()
plt.xlabel('Period')
plt.ylabel('Number of Homes Sold')
plt.title('Number of Homes Sold in New York County, NY in 2020')
plt.savefig("abigail/homessold2020.png")
plt.show()

# %%
#Generate Line Plot of Total Homes Sold in 2020

plt.style.use('seaborn-whitegrid')
dates = newyork2020_county['period_begin']
dates = pd.to_datetime(dates)
plt.plot(dates,newyork2020_county['total_new_listings'],color = 'red')
plt.gcf().autofmt_xdate()
plt.xlabel('Period')
plt.ylabel('New Home Listings')
plt.title('New Home Listings in New York County, NY in 2020')
plt.savefig("abigail/newhomelistings2020.png")
plt.show()
